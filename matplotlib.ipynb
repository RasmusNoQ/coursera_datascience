# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.title('Data Visualization using PyPlot of Matplotlib')
# Out:
# Text(0.5, 1.0, 'Data Visualization using PyPlot of Matplotlib')

# %%
plt.show()

# %%
plt.axis([0,6,0,12])
# Out:
# (0.0, 6.0, 0.0, 12.0)

# %%
plt.plot(x*2,'g^',x*3,'rs',x**x,'y-')
# Out:
# [<matplotlib.lines.Line2D at 0x7f6326e0a150>,
#  <matplotlib.lines.Line2D at 0x7f6326e0a190>,
#  <matplotlib.lines.Line2D at 0x7f6326e0a810>]

# %%
line = plt.plot(y,color='red',linewidth=2.0)
